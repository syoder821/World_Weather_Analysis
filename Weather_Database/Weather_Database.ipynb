# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import json

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 740

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | saldanha
# Processing Record 2 of Set 1 | cahors
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | jucurutu
# Processing Record 5 of Set 1 | port elizabeth
# Processing Record 6 of Set 1 | salinas
# Processing Record 7 of Set 1 | kurumkan
# Processing Record 8 of Set 1 | karatuzskoye
# Processing Record 9 of Set 1 | torbay
# Processing Record 10 of Set 1 | tongchuan
# Processing Record 11 of Set 1 | general roca
# Processing Record 12 of Set 1 | lima
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | georgetown
# Processing Record 15 of Set 1 | tiznit
# Processing Record 16 of Set 1 | khatanga
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | clyde river
# Processing Record 19 of Set 1 | garissa
# Processing Record 20 of Set 1 | coihaique
# Processing Record 21 of Set 1 | meulaboh
# Processing Record 22 of Set 1 | chapais
# Processing Record 23 of Set 1 | college
# Processing Record 24 of Set 1 | calatayud
# Processing Record 25 of Set 1 | kavieng
# Processing Record 26 of Set 1 | kruisfontein
# Processing Record 27 of Set 1 | owando
# Processing Record 28 of Set 1 | touros
# Processing Record 29 of Set 1 | san quintin
# Processing Record 30 of Set 1 | chuy
# Processing Record 31 of Set 1 | mahanoro
# Processing Record 32 of Set 1 | hobart
# Processing Record 33 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 34 of Set 1 | san jose
# Processing Record 35 of Set 1 | helong
# Processing Record 36 of Set 1 | hami
# Processing Record 37 of Set 1 | taldan
# Processing Record 38 of Set 1 | nizhniy odes
# Processing Record 39 of Set 1 | tuktoyaktuk
# Processing Record 40 of Set 1 | sioux lookout
# Processing Record 41 of Set 1 | jasper
# Processing Record 42 of Set 1 | komsomolskiy
# Processing Record 43 of Set 1 | iqaluit
# Processing Record 44 of Set 1 | ilulissat
# Processing Record 45 of Set 1 | nanakuli
# Processing Record 46 of Set 1 | yellowknife
# Processing Record 47 of Set 1 | shiyan
# Processing Record 48 of Set 1 | acapulco
# Processing Record 49 of Set 1 | mataura
# Processing Record 50 of Set 1 | qaanaaq
# Processing Record 1 of Set 2 | castro
# Processing Record 2 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 2 | ondangwa
# Processing Record 4 of Set 2 | ponferrada
# Processing Record 5 of Set 2 | bara
# Processing Record 6 of Set 2 | shasta lake
# Processing Record 7 of Set 2 | port alfred
# Processing Record 8 of Set 2 | punta arenas
# Processing Record 9 of Set 2 | tasiilaq
# Processing Record 10 of Set 2 | brae
# Processing Record 11 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 2 | atuona
# Processing Record 13 of Set 2 | bandarbeyla
# Processing Record 14 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 2 | sao joao da barra
# Processing Record 16 of Set 2 | bathsheba
# Processing Record 17 of Set 2 | ushuaia
# Processing Record 18 of Set 2 | lagoa
# Processing Record 19 of Set 2 | mehamn
# Processing Record 20 of Set 2 | awassa
# Processing Record 21 of Set 2 | bethel
# Processing Record 22 of Set 2 | kodiak
# Processing Record 23 of Set 2 | busselton
# Processing Record 24 of Set 2 | salalah
# Processing Record 25 of Set 2 | tiksi
# Processing Record 26 of Set 2 | tessalit
# Processing Record 27 of Set 2 | broome
# Processing Record 28 of Set 2 | rikitea
# Processing Record 29 of Set 2 | krasnoye
# Processing Record 30 of Set 2 | tianpeng
# Processing Record 31 of Set 2 | dabola
# Processing Record 32 of Set 2 | rongcheng
# Processing Record 33 of Set 2 | solnechnyy
# Processing Record 34 of Set 2 | bjornevatn
# Processing Record 35 of Set 2 | egvekinot
# Processing Record 36 of Set 2 | lebu
# Processing Record 37 of Set 2 | avarua
# Processing Record 38 of Set 2 | atherton
# Processing Record 39 of Set 2 | jamestown
# Processing Record 40 of Set 2 | anadyr
# Processing Record 41 of Set 2 | cayenne
# Processing Record 42 of Set 2 | butaritari
# Processing Record 43 of Set 2 | isla mujeres
# Processing Record 44 of Set 2 | kathmandu
# Processing Record 45 of Set 2 | santa rosa
# Processing Record 46 of Set 2 | vardo
# Processing Record 47 of Set 2 | hermanus
# Processing Record 48 of Set 2 | hofn
# Processing Record 49 of Set 2 | kailua
# Processing Record 50 of Set 2 | hilo
# Processing Record 1 of Set 3 | flagstaff
# Processing Record 2 of Set 3 | thompson
# Processing Record 3 of Set 3 | garden city
# Processing Record 4 of Set 3 | payo
# Processing Record 5 of Set 3 | hagi
# Processing Record 6 of Set 3 | lac du bonnet
# Processing Record 7 of Set 3 | zyryanka
# Processing Record 8 of Set 3 | nelson bay
# Processing Record 9 of Set 3 | new norfolk
# Processing Record 10 of Set 3 | galesong
# Processing Record 11 of Set 3 | bubaque
# Processing Record 12 of Set 3 | mwene-ditu
# Processing Record 13 of Set 3 | nouadhibou
# Processing Record 14 of Set 3 | ishigaki
# Processing Record 15 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 3 | mimongo
# Processing Record 17 of Set 3 | north bend
# Processing Record 18 of Set 3 | aklavik
# Processing Record 19 of Set 3 | riwaka
# Processing Record 20 of Set 3 | stupino
# Processing Record 21 of Set 3 | cotonou
# Processing Record 22 of Set 3 | ribeira grande
# Processing Record 23 of Set 3 | dikson
# Processing Record 24 of Set 3 | olafsvik
# Processing Record 25 of Set 3 | zasheyek
# Processing Record 26 of Set 3 | sisimiut
# Processing Record 27 of Set 3 | geraldton
# Processing Record 28 of Set 3 | yulara
# Processing Record 29 of Set 3 | buraydah
# Processing Record 30 of Set 3 | bluff
# Processing Record 31 of Set 3 | richards bay
# Processing Record 32 of Set 3 | zhigansk
# Processing Record 33 of Set 3 | broken hill
# Processing Record 34 of Set 3 | mweka
# Processing Record 35 of Set 3 | toora-khem
# Processing Record 36 of Set 3 | goderich
# Processing Record 37 of Set 3 | vila velha
# Processing Record 38 of Set 3 | paraiso
# Processing Record 39 of Set 3 | troitskoye
# Processing Record 40 of Set 3 | san cristobal
# Processing Record 41 of Set 3 | arraial do cabo
# Processing Record 42 of Set 3 | ugoofaaru
# Processing Record 43 of Set 3 | ergani
# Processing Record 44 of Set 3 | uribia
# Processing Record 45 of Set 3 | fuxin
# Processing Record 46 of Set 3 | taiyuan
# Processing Record 47 of Set 3 | koslan
# Processing Record 48 of Set 3 | saint-philippe
# Processing Record 49 of Set 3 | harper
# Processing Record 50 of Set 3 | xining
# Processing Record 1 of Set 4 | nhulunbuy
# Processing Record 2 of Set 4 | yar-sale
# Processing Record 3 of Set 4 | amahai
# Processing Record 4 of Set 4 | mahadday weyne
# City not found. Skipping...
# Processing Record 5 of Set 4 | manali
# Processing Record 6 of Set 4 | kapaa
# Processing Record 7 of Set 4 | luwingu
# Processing Record 8 of Set 4 | stargard szczecinski
# Processing Record 9 of Set 4 | bayshore gardens
# Processing Record 10 of Set 4 | isla aguada
# Processing Record 11 of Set 4 | raga
# Processing Record 12 of Set 4 | sain alto
# Processing Record 13 of Set 4 | upernavik
# Processing Record 14 of Set 4 | abonnema
# Processing Record 15 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 4 | bonavista
# Processing Record 17 of Set 4 | tukrah
# Processing Record 18 of Set 4 | hervey bay
# Processing Record 19 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 4 | muncie
# Processing Record 21 of Set 4 | kahului
# Processing Record 22 of Set 4 | jurm
# Processing Record 23 of Set 4 | boone
# Processing Record 24 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 4 | norman wells
# Processing Record 26 of Set 4 | salinopolis
# Processing Record 27 of Set 4 | la ronge
# Processing Record 28 of Set 4 | saint george
# Processing Record 29 of Set 4 | alofi
# Processing Record 30 of Set 4 | patitirion
# Processing Record 31 of Set 4 | kavaratti
# Processing Record 32 of Set 4 | adrar
# Processing Record 33 of Set 4 | airai
# Processing Record 34 of Set 4 | gibara
# Processing Record 35 of Set 4 | aleksandrov gay
# Processing Record 36 of Set 4 | thinadhoo
# Processing Record 37 of Set 4 | mackay
# Processing Record 38 of Set 4 | provideniya
# Processing Record 39 of Set 4 | skjervoy
# Processing Record 40 of Set 4 | jamame
# Processing Record 41 of Set 4 | quang ngai
# Processing Record 42 of Set 4 | road town
# Processing Record 43 of Set 4 | fare
# Processing Record 44 of Set 4 | boa vista
# Processing Record 45 of Set 4 | kaitangata
# Processing Record 46 of Set 4 | ancud
# Processing Record 47 of Set 4 | evensk
# Processing Record 48 of Set 4 | kloulklubed
# Processing Record 49 of Set 4 | hithadhoo
# Processing Record 50 of Set 4 | streator
# Processing Record 1 of Set 5 | luderitz
# Processing Record 2 of Set 5 | nome
# Processing Record 3 of Set 5 | barrow
# Processing Record 4 of Set 5 | gomel
# Processing Record 5 of Set 5 | port hedland
# Processing Record 6 of Set 5 | naryan-mar
# Processing Record 7 of Set 5 | lugovskoy
# Processing Record 8 of Set 5 | pevek
# Processing Record 9 of Set 5 | sagar
# Processing Record 10 of Set 5 | klaksvik
# Processing Record 11 of Set 5 | pargolovo
# Processing Record 12 of Set 5 | coxim
# Processing Record 13 of Set 5 | mar del plata
# Processing Record 14 of Set 5 | rio gallegos
# Processing Record 15 of Set 5 | longyearbyen
# Processing Record 16 of Set 5 | saint-augustin
# Processing Record 17 of Set 5 | menongue
# Processing Record 18 of Set 5 | bengkulu
# Processing Record 19 of Set 5 | norden
# Processing Record 20 of Set 5 | souillac
# Processing Record 21 of Set 5 | puerto ayora
# Processing Record 22 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 23 of Set 5 | kerava
# Processing Record 24 of Set 5 | kaduqli
# Processing Record 25 of Set 5 | kalianget
# Processing Record 26 of Set 5 | hamilton
# Processing Record 27 of Set 5 | isangel
# Processing Record 28 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 5 | narsaq
# Processing Record 30 of Set 5 | caxito
# Processing Record 31 of Set 5 | raymond
# Processing Record 32 of Set 5 | belaya gora
# Processing Record 33 of Set 5 | vostok
# Processing Record 34 of Set 5 | san andres
# Processing Record 35 of Set 5 | axim
# Processing Record 36 of Set 5 | parkersburg
# Processing Record 37 of Set 5 | bentiu
# Processing Record 38 of Set 5 | malangwa
# Processing Record 39 of Set 5 | sabang
# Processing Record 40 of Set 5 | bressuire
# Processing Record 41 of Set 5 | laguna
# Processing Record 42 of Set 5 | ust-tsilma
# Processing Record 43 of Set 5 | constitucion
# Processing Record 44 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 5 | jumla
# Processing Record 46 of Set 5 | chifeng
# Processing Record 47 of Set 5 | uyuni
# Processing Record 48 of Set 5 | cidreira
# Processing Record 49 of Set 5 | bunol
# Processing Record 50 of Set 5 | barkhan
# Processing Record 1 of Set 6 | buckeye
# Processing Record 2 of Set 6 | athabasca
# Processing Record 3 of Set 6 | sterling
# Processing Record 4 of Set 6 | verkhnevilyuysk
# Processing Record 5 of Set 6 | okhotsk
# Processing Record 6 of Set 6 | araouane
# Processing Record 7 of Set 6 | lavrentiya
# Processing Record 8 of Set 6 | kirkwall
# Processing Record 9 of Set 6 | talnakh
# Processing Record 10 of Set 6 | saskylakh
# Processing Record 11 of Set 6 | drumheller
# Processing Record 12 of Set 6 | dubbo
# Processing Record 13 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 6 | naze
# Processing Record 15 of Set 6 | faanui
# Processing Record 16 of Set 6 | dauphin
# Processing Record 17 of Set 6 | jorpeland
# Processing Record 18 of Set 6 | maniitsoq
# Processing Record 19 of Set 6 | mantua
# Processing Record 20 of Set 6 | khingansk
# Processing Record 21 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 6 | kinarut
# Processing Record 23 of Set 6 | canton
# Processing Record 24 of Set 6 | bacuit
# City not found. Skipping...
# Processing Record 25 of Set 6 | hire
# City not found. Skipping...
# Processing Record 26 of Set 6 | beringovskiy
# Processing Record 27 of Set 6 | tabou
# Processing Record 28 of Set 6 | paamiut
# Processing Record 29 of Set 6 | port moresby
# Processing Record 30 of Set 6 | bambous virieux
# Processing Record 31 of Set 6 | faro
# Processing Record 32 of Set 6 | lata
# Processing Record 33 of Set 6 | starosubkhangulovo
# Processing Record 34 of Set 6 | lorengau
# Processing Record 35 of Set 6 | andevoranto
# City not found. Skipping...
# Processing Record 36 of Set 6 | takab
# Processing Record 37 of Set 6 | siyabuswa
# Processing Record 38 of Set 6 | severo-kurilsk
# Processing Record 39 of Set 6 | mbeya
# Processing Record 40 of Set 6 | quatre cocos
# Processing Record 41 of Set 6 | mattru
# Processing Record 42 of Set 6 | sur
# Processing Record 43 of Set 6 | buzmeyin
# Processing Record 44 of Set 6 | waitati
# Processing Record 45 of Set 6 | zavitinsk
# Processing Record 46 of Set 6 | haines junction
# Processing Record 47 of Set 6 | hasaki
# Processing Record 48 of Set 6 | marzuq
# Processing Record 49 of Set 6 | santa maria
# Processing Record 50 of Set 6 | nikolskoye
# Processing Record 1 of Set 7 | zhoukou
# Processing Record 2 of Set 7 | camacha
# Processing Record 3 of Set 7 | abu samrah
# Processing Record 4 of Set 7 | ntcheu
# Processing Record 5 of Set 7 | yanchukan
# City not found. Skipping...
# Processing Record 6 of Set 7 | lasa
# Processing Record 7 of Set 7 | pangnirtung
# Processing Record 8 of Set 7 | cherskiy
# Processing Record 9 of Set 7 | nanortalik
# Processing Record 10 of Set 7 | raudeberg
# Processing Record 11 of Set 7 | winnemucca
# Processing Record 12 of Set 7 | caibiran
# Processing Record 13 of Set 7 | sheridan
# Processing Record 14 of Set 7 | tanda
# Processing Record 15 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 7 | victoria
# Processing Record 17 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 7 | grants
# Processing Record 19 of Set 7 | ponta do sol
# Processing Record 20 of Set 7 | caravelas
# Processing Record 21 of Set 7 | jibuti
# Processing Record 22 of Set 7 | malanje
# Processing Record 23 of Set 7 | bredasdorp
# Processing Record 24 of Set 7 | am timan
# Processing Record 25 of Set 7 | jiuquan
# Processing Record 26 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 27 of Set 7 | carnarvon
# Processing Record 28 of Set 7 | leshukonskoye
# Processing Record 29 of Set 7 | palakkodu
# Processing Record 30 of Set 7 | mount gambier
# Processing Record 31 of Set 7 | cabo san lucas
# Processing Record 32 of Set 7 | santo domingo
# Processing Record 33 of Set 7 | sile
# Processing Record 34 of Set 7 | guna
# Processing Record 35 of Set 7 | loikaw
# Processing Record 36 of Set 7 | mandalgovi
# Processing Record 37 of Set 7 | kuusamo
# Processing Record 38 of Set 7 | comodoro rivadavia
# Processing Record 39 of Set 7 | nefteyugansk
# Processing Record 40 of Set 7 | portland
# Processing Record 41 of Set 7 | kommunisticheskiy
# Processing Record 42 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 7 | labuhan
# Processing Record 44 of Set 7 | anchorage
# Processing Record 45 of Set 7 | olinda
# Processing Record 46 of Set 7 | te anau
# Processing Record 47 of Set 7 | pasni
# Processing Record 48 of Set 7 | bitung
# Processing Record 49 of Set 7 | roald
# Processing Record 50 of Set 7 | vila franca do campo
# Processing Record 1 of Set 8 | krasnoselkup
# Processing Record 2 of Set 8 | necochea
# Processing Record 3 of Set 8 | lompoc
# Processing Record 4 of Set 8 | east london
# Processing Record 5 of Set 8 | honiara
# Processing Record 6 of Set 8 | winfield
# Processing Record 7 of Set 8 | mayo
# Processing Record 8 of Set 8 | fortuna
# Processing Record 9 of Set 8 | gushikawa
# Processing Record 10 of Set 8 | halifax
# Processing Record 11 of Set 8 | kurchum
# Processing Record 12 of Set 8 | shemonaikha
# Processing Record 13 of Set 8 | esperance
# Processing Record 14 of Set 8 | saint-georges
# Processing Record 15 of Set 8 | winslow
# Processing Record 16 of Set 8 | tadine
# Processing Record 17 of Set 8 | boralday
# Processing Record 18 of Set 8 | champaign
# Processing Record 19 of Set 8 | sao geraldo do araguaia
# Processing Record 20 of Set 8 | fairview
# Processing Record 21 of Set 8 | guerrero negro
# Processing Record 22 of Set 8 | kaputa
# Processing Record 23 of Set 8 | hwange
# Processing Record 24 of Set 8 | rasuceni
# Processing Record 25 of Set 8 | pitimbu
# Processing Record 26 of Set 8 | katsuura
# Processing Record 27 of Set 8 | thanjavur
# Processing Record 28 of Set 8 | demirci
# Processing Record 29 of Set 8 | annamalainagar
# Processing Record 30 of Set 8 | nouna
# Processing Record 31 of Set 8 | daru
# Processing Record 32 of Set 8 | sao luiz gonzaga
# Processing Record 33 of Set 8 | ust-maya
# Processing Record 34 of Set 8 | ankazoabo
# Processing Record 35 of Set 8 | thunder bay
# Processing Record 36 of Set 8 | zlitan
# Processing Record 37 of Set 8 | tezu
# Processing Record 38 of Set 8 | mason city
# Processing Record 39 of Set 8 | kutum
# Processing Record 40 of Set 8 | seryshevo
# Processing Record 41 of Set 8 | vengerovo
# Processing Record 42 of Set 8 | belmonte
# Processing Record 43 of Set 8 | mahebourg
# Processing Record 44 of Set 8 | caucaia
# Processing Record 45 of Set 8 | wahran
# City not found. Skipping...
# Processing Record 46 of Set 8 | dawlatabad
# Processing Record 47 of Set 8 | moerai
# Processing Record 48 of Set 8 | ostrovnoy
# Processing Record 49 of Set 8 | qingdao
# Processing Record 50 of Set 8 | tuatapere
# Processing Record 1 of Set 9 | wewak
# Processing Record 2 of Set 9 | flinders
# Processing Record 3 of Set 9 | bom jesus
# Processing Record 4 of Set 9 | himare
# Processing Record 5 of Set 9 | chicama
# Processing Record 6 of Set 9 | srednekolymsk
# Processing Record 7 of Set 9 | pekan
# Processing Record 8 of Set 9 | yerbogachen
# Processing Record 9 of Set 9 | mnogovershinnyy
# Processing Record 10 of Set 9 | isiro
# Processing Record 11 of Set 9 | kungurtug
# Processing Record 12 of Set 9 | vanavara
# Processing Record 13 of Set 9 | nemuro
# Processing Record 14 of Set 9 | bassila
# Processing Record 15 of Set 9 | vicuna
# Processing Record 16 of Set 9 | willowmore
# Processing Record 17 of Set 9 | itaituba
# Processing Record 18 of Set 9 | ritchie
# Processing Record 19 of Set 9 | stutterheim
# Processing Record 20 of Set 9 | koindu
# Processing Record 21 of Set 9 | den helder
# Processing Record 22 of Set 9 | codrington
# Processing Record 23 of Set 9 | zlatoustovsk
# City not found. Skipping...
# Processing Record 24 of Set 9 | igarka
# Processing Record 25 of Set 9 | safranbolu
# Processing Record 26 of Set 9 | dhidhdhoo
# Processing Record 27 of Set 9 | clearlake
# Processing Record 28 of Set 9 | ambon
# Processing Record 29 of Set 9 | leningradskiy
# Processing Record 30 of Set 9 | manggar
# Processing Record 31 of Set 9 | chervone
# Processing Record 32 of Set 9 | kuytun
# Processing Record 33 of Set 9 | borba
# Processing Record 34 of Set 9 | avanigadda
# Processing Record 35 of Set 9 | umm lajj
# Processing Record 36 of Set 9 | mazamari
# Processing Record 37 of Set 9 | kushmurun
# Processing Record 38 of Set 9 | osypenko
# Processing Record 39 of Set 9 | celestun
# Processing Record 40 of Set 9 | schleswig
# Processing Record 41 of Set 9 | norwalk
# Processing Record 42 of Set 9 | ulladulla
# Processing Record 43 of Set 9 | bodmin
# Processing Record 44 of Set 9 | ano komi
# Processing Record 45 of Set 9 | zalantun
# Processing Record 46 of Set 9 | gualeguaychu
# Processing Record 47 of Set 9 | gat
# Processing Record 48 of Set 9 | cam ranh
# Processing Record 49 of Set 9 | aquiraz
# Processing Record 50 of Set 9 | bayonet point
# Processing Record 1 of Set 10 | rio tuba
# Processing Record 2 of Set 10 | sangar
# Processing Record 3 of Set 10 | los llanos de aridane
# Processing Record 4 of Set 10 | bosaso
# Processing Record 5 of Set 10 | alim
# Processing Record 6 of Set 10 | hay river
# Processing Record 7 of Set 10 | atasu
# Processing Record 8 of Set 10 | gimli
# Processing Record 9 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 10 of Set 10 | sidi ali
# Processing Record 11 of Set 10 | eureka
# Processing Record 12 of Set 10 | canchungo
# Processing Record 13 of Set 10 | havoysund
# Processing Record 14 of Set 10 | sri aman
# Processing Record 15 of Set 10 | aksu
# Processing Record 16 of Set 10 | north myrtle beach
# Processing Record 17 of Set 10 | charters towers
# Processing Record 18 of Set 10 | port hardy
# Processing Record 19 of Set 10 | vao
# Processing Record 20 of Set 10 | aldine
# Processing Record 21 of Set 10 | padang
# Processing Record 22 of Set 10 | holme
# Processing Record 23 of Set 10 | sinnamary
# Processing Record 24 of Set 10 | maragogi
# Processing Record 25 of Set 10 | taywarah
# Processing Record 26 of Set 10 | wanning
# Processing Record 27 of Set 10 | tandil
# Processing Record 28 of Set 10 | tura
# Processing Record 29 of Set 10 | rawson
# Processing Record 30 of Set 10 | bin qirdan
# Processing Record 31 of Set 10 | coahuayana
# Processing Record 32 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 33 of Set 10 | tigil
# Processing Record 34 of Set 10 | sirajganj
# Processing Record 35 of Set 10 | dwarka
# Processing Record 36 of Set 10 | uturoa
# Processing Record 37 of Set 10 | darlowo
# Processing Record 38 of Set 10 | lexington
# Processing Record 39 of Set 10 | nipawin
# Processing Record 40 of Set 10 | west bay
# Processing Record 41 of Set 10 | nortelandia
# Processing Record 42 of Set 10 | itoman
# Processing Record 43 of Set 10 | galle
# Processing Record 44 of Set 10 | port blair
# Processing Record 45 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 10 | kidal
# Processing Record 47 of Set 10 | dovolnoye
# Processing Record 48 of Set 10 | sao paulo de olivenca
# Processing Record 49 of Set 10 | razole
# Processing Record 50 of Set 10 | punta alta
# Processing Record 1 of Set 11 | barmer
# Processing Record 2 of Set 11 | sitka
# Processing Record 3 of Set 11 | tiarei
# Processing Record 4 of Set 11 | huarmey
# Processing Record 5 of Set 11 | itanagar
# Processing Record 6 of Set 11 | molodizhne
# Processing Record 7 of Set 11 | vredendal
# Processing Record 8 of Set 11 | nalut
# Processing Record 9 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 10 of Set 11 | sola
# Processing Record 11 of Set 11 | labelle
# Processing Record 12 of Set 11 | sobolevo
# Processing Record 13 of Set 11 | xichang
# Processing Record 14 of Set 11 | saint-denis
# Processing Record 15 of Set 11 | tignere
# Processing Record 16 of Set 11 | sao miguel do araguaia
# Processing Record 17 of Set 11 | lakes entrance
# Processing Record 18 of Set 11 | marystown
# Processing Record 19 of Set 11 | manacapuru
# Processing Record 20 of Set 11 | madanapalle
# Processing Record 21 of Set 11 | chipinge
# Processing Record 22 of Set 11 | taltal
# Processing Record 23 of Set 11 | svetlyy
# Processing Record 24 of Set 11 | san carlos de bariloche
# Processing Record 25 of Set 11 | weyburn
# Processing Record 26 of Set 11 | ixtapa
# Processing Record 27 of Set 11 | verkhnyaya inta
# Processing Record 28 of Set 11 | sao filipe
# Processing Record 29 of Set 11 | santa marta
# Processing Record 30 of Set 11 | waingapu
# Processing Record 31 of Set 11 | sistranda
# Processing Record 32 of Set 11 | kuznechnoye
# Processing Record 33 of Set 11 | kijang
# Processing Record 34 of Set 11 | primo tapia
# Processing Record 35 of Set 11 | zhuzhou
# Processing Record 36 of Set 11 | hualmay
# Processing Record 37 of Set 11 | keti bandar
# Processing Record 38 of Set 11 | arraias
# Processing Record 39 of Set 11 | viedma
# Processing Record 40 of Set 11 | grindavik
# Processing Record 41 of Set 11 | buariki
# City not found. Skipping...
# Processing Record 42 of Set 11 | abbeville
# Processing Record 43 of Set 11 | reichenau
# Processing Record 44 of Set 11 | astoria
# Processing Record 45 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 46 of Set 11 | yurkivka
# Processing Record 47 of Set 11 | ketchikan
# Processing Record 48 of Set 11 | marsh harbour
# Processing Record 49 of Set 11 | lodja
# Processing Record 50 of Set 11 | wukari
# Processing Record 1 of Set 12 | hokitika
# Processing Record 2 of Set 12 | chokurdakh
# Processing Record 3 of Set 12 | atar
# Processing Record 4 of Set 12 | gazojak
# Processing Record 5 of Set 12 | yelabuga
# Processing Record 6 of Set 12 | port victoria
# Processing Record 7 of Set 12 | aswan
# Processing Record 8 of Set 12 | xai-xai
# Processing Record 9 of Set 12 | alberton
# Processing Record 10 of Set 12 | vila
# Processing Record 11 of Set 12 | roseburg
# Processing Record 12 of Set 12 | buenos aires
# Processing Record 13 of Set 12 | kapoeta
# Processing Record 14 of Set 12 | samarai
# Processing Record 15 of Set 12 | berlevag
# Processing Record 16 of Set 12 | porbandar
# Processing Record 17 of Set 12 | villa maria
# Processing Record 18 of Set 12 | neiafu
# Processing Record 19 of Set 12 | ardakan
# Processing Record 20 of Set 12 | altamont
# Processing Record 21 of Set 12 | panji
# Processing Record 22 of Set 12 | port lincoln
# Processing Record 23 of Set 12 | coquimbo
# Processing Record 24 of Set 12 | mach
# Processing Record 25 of Set 12 | labuan
# Processing Record 26 of Set 12 | vestmannaeyjar
# Processing Record 27 of Set 12 | san patricio
# Processing Record 28 of Set 12 | dombarovskiy
# Processing Record 29 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 30 of Set 12 | serebryansk
# Processing Record 31 of Set 12 | koungou
# Processing Record 32 of Set 12 | loreto
# Processing Record 33 of Set 12 | weiser
# Processing Record 34 of Set 12 | mahibadhoo
# Processing Record 35 of Set 12 | vila do maio
# Processing Record 36 of Set 12 | cairns
# Processing Record 37 of Set 12 | husavik
# Processing Record 38 of Set 12 | alice springs
# Processing Record 39 of Set 12 | rundu
# Processing Record 40 of Set 12 | san pedro
# Processing Record 41 of Set 12 | half moon bay
# Processing Record 42 of Set 12 | safaqis
# City not found. Skipping...
# Processing Record 43 of Set 12 | prince rupert
# Processing Record 44 of Set 12 | yarkovo
# Processing Record 45 of Set 12 | kolokani
# Processing Record 46 of Set 12 | muros
# Processing Record 47 of Set 12 | ngunguru
# Processing Record 48 of Set 12 | inyonga
# Processing Record 49 of Set 12 | fairbanks
# Processing Record 50 of Set 12 | zhanatas
# City not found. Skipping...
# Processing Record 1 of Set 13 | aranos
# Processing Record 2 of Set 13 | black river
# Processing Record 3 of Set 13 | coron
# Processing Record 4 of Set 13 | rio grande
# Processing Record 5 of Set 13 | paka
# Processing Record 6 of Set 13 | el alto
# Processing Record 7 of Set 13 | ouahigouya
# Processing Record 8 of Set 13 | alyangula
# Processing Record 9 of Set 13 | hebertville
# City not found. Skipping...
# Processing Record 10 of Set 13 | yumen
# Processing Record 11 of Set 13 | krasnogorsk
# Processing Record 12 of Set 13 | camapua
# Processing Record 13 of Set 13 | trapani
# Processing Record 14 of Set 13 | voskresenskoye
# Processing Record 15 of Set 13 | ponta delgada
# Processing Record 16 of Set 13 | namibe
# Processing Record 17 of Set 13 | namatanai
# Processing Record 18 of Set 13 | mount isa
# Processing Record 19 of Set 13 | konibodom
# Processing Record 20 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 21 of Set 13 | manokwari
# Processing Record 22 of Set 13 | segezha
# Processing Record 23 of Set 13 | grand gaube
# Processing Record 24 of Set 13 | shingu
# Processing Record 25 of Set 13 | lubango
# Processing Record 26 of Set 13 | inirida
# Processing Record 27 of Set 13 | sabla
# Processing Record 28 of Set 13 | sandpoint
# Processing Record 29 of Set 13 | kysyl-syr
# Processing Record 30 of Set 13 | javanrud
# Processing Record 31 of Set 13 | umm kaddadah
# Processing Record 32 of Set 13 | zhitikara
# City not found. Skipping...
# Processing Record 33 of Set 13 | campulung
# Processing Record 34 of Set 13 | paita
# Processing Record 35 of Set 13 | gazanjyk
# Processing Record 36 of Set 13 | acari
# Processing Record 37 of Set 13 | yeppoon
# Processing Record 38 of Set 13 | bafra
# Processing Record 39 of Set 13 | maarianhamina
# Processing Record 40 of Set 13 | yilan
# Processing Record 41 of Set 13 | humaita
# Processing Record 42 of Set 13 | cumaribo
# City not found. Skipping...
# Processing Record 43 of Set 13 | dudinka
# Processing Record 44 of Set 13 | sambava
# Processing Record 45 of Set 13 | najran
# Processing Record 46 of Set 13 | arlit
# Processing Record 47 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 48 of Set 13 | zeya
# Processing Record 49 of Set 13 | lillooet
# Processing Record 50 of Set 13 | port macquarie
# Processing Record 1 of Set 14 | braslav
# City not found. Skipping...
# Processing Record 2 of Set 14 | aanekoski
# Processing Record 3 of Set 14 | lazaro cardenas
# Processing Record 4 of Set 14 | arauco
# Processing Record 5 of Set 14 | alekseyevsk
# Processing Record 6 of Set 14 | bonthe
# Processing Record 7 of Set 14 | bangkalan
# Processing Record 8 of Set 14 | chikitigarh
# Processing Record 9 of Set 14 | waipawa
# Processing Record 10 of Set 14 | kawalu
# Processing Record 11 of Set 14 | mundo nuevo
# Processing Record 12 of Set 14 | saint anthony
# Processing Record 13 of Set 14 | pacifica
# Processing Record 14 of Set 14 | abong mbang
# Processing Record 15 of Set 14 | whitehorse
# Processing Record 16 of Set 14 | iquique
# Processing Record 17 of Set 14 | zhuhai
# Processing Record 18 of Set 14 | obarsia-closani
# City not found. Skipping...
# Processing Record 19 of Set 14 | viersen
# Processing Record 20 of Set 14 | cartagena
# Processing Record 21 of Set 14 | dingle
# Processing Record 22 of Set 14 | kota
# Processing Record 23 of Set 14 | chadiza
# Processing Record 24 of Set 14 | maputo
# Processing Record 25 of Set 14 | putina
# Processing Record 26 of Set 14 | kerki
# City not found. Skipping...
# Processing Record 27 of Set 14 | antofagasta
# Processing Record 28 of Set 14 | andenes
# Processing Record 29 of Set 14 | aykhal
# Processing Record 30 of Set 14 | port hawkesbury
# Processing Record 31 of Set 14 | cradock
# Processing Record 32 of Set 14 | xuddur
# Processing Record 33 of Set 14 | oranjestad
# Processing Record 34 of Set 14 | arica
# Processing Record 35 of Set 14 | faya
# Processing Record 36 of Set 14 | dongsheng
# Processing Record 37 of Set 14 | hun
# Processing Record 38 of Set 14 | davila
# Processing Record 39 of Set 14 | encantado
# Processing Record 40 of Set 14 | walvis bay
# Processing Record 41 of Set 14 | avera
# Processing Record 42 of Set 14 | la primavera
# Processing Record 43 of Set 14 | oksbol
# Processing Record 44 of Set 14 | kununurra
# Processing Record 45 of Set 14 | shihezi
# Processing Record 46 of Set 14 | grand-lahou
# Processing Record 47 of Set 14 | solovetskiy
# City not found. Skipping...
# Processing Record 48 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 14 | ayan
# Processing Record 50 of Set 14 | inhambane
# Processing Record 1 of Set 15 | morgan city
# Processing Record 2 of Set 15 | tautira
# Processing Record 3 of Set 15 | danielskuil
# Processing Record 4 of Set 15 | linxia
# Processing Record 5 of Set 15 | mitsamiouli
# Processing Record 6 of Set 15 | challapata
# Processing Record 7 of Set 15 | melo
# Processing Record 8 of Set 15 | maple creek
# Processing Record 9 of Set 15 | changtu
# Processing Record 10 of Set 15 | port-gentil
# Processing Record 11 of Set 15 | westport
# Processing Record 12 of Set 15 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 13 of Set 15 | ormond beach
# Processing Record 14 of Set 15 | felidhoo
# City not found. Skipping...
# Processing Record 15 of Set 15 | karratha
# Processing Record 16 of Set 15 | saraland
# Processing Record 17 of Set 15 | diamantina
# Processing Record 18 of Set 15 | denpasar
# Processing Record 19 of Set 15 | svetlogorsk
# Processing Record 20 of Set 15 | trairi
# Processing Record 21 of Set 15 | the pas
# Processing Record 22 of Set 15 | san juan
# Processing Record 23 of Set 15 | margate
# Processing Record 24 of Set 15 | qaqortoq
# Processing Record 25 of Set 15 | gornopravdinsk
# Processing Record 26 of Set 15 | hvammstangi
# City not found. Skipping...
# Processing Record 27 of Set 15 | polyarnyy
# Processing Record 28 of Set 15 | bandar-e lengeh
# Processing Record 29 of Set 15 | filadelfia
# Processing Record 30 of Set 15 | salym
# Processing Record 31 of Set 15 | chimala
# Processing Record 32 of Set 15 | ennis
# Processing Record 33 of Set 15 | sarahan
# Processing Record 34 of Set 15 | poum
# Processing Record 35 of Set 15 | kuopio
# Processing Record 36 of Set 15 | itaguai
# Processing Record 37 of Set 15 | colac
# Processing Record 38 of Set 15 | anlu
# Processing Record 39 of Set 15 | kolondieba
# Processing Record 40 of Set 15 | trincomalee
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 694

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# Reorder columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Saldanha      ZA -33.0117   17.9442     57.25        97          15
# 1          Cahors      FR  44.4167    1.3333     47.70        82           0
# 2       Cape Town      ZA -33.9258   18.4232     59.09        73          40
# 3        Jucurutu      BR  -6.0339  -37.0203     85.60        56          89
# 4  Port Elizabeth      ZA -33.9180   25.5701     67.10        82         100
# 5         Salinas      US  36.6777 -121.6555     76.01        60          75
# 6        Kurumkan      RU  54.3000  110.3000     30.72        69          76
# 7    Karatuzskoye      RU  53.6072   92.8667     33.57        95         100
# 8          Torbay      CA  47.6666  -52.7314     52.75        67          40
# 9       Tongchuan      CN  35.0806  109.0897     51.80        89          79
#
#    Wind Speed Current Description
# 0       13.65          few clouds
# 1        5.68           clear sky
# 2       16.11    scattered clouds
# 3       10.49     overcast clouds
# 4        8.19     overcast clouds
# 5       14.97       broken clouds
# 6        1.79       broken clouds
# 7       14.00          light rain
# 8        6.91    scattered clouds
# 9        4.65       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file)
